# %%
import time
import requests
import os
import bs4
import requests
from selenium import webdriver

DRIVER_PATH = '/home/adithya/Downloads/chromedriver_linux64/chromedriver'

folder_name = './wildlife/'
def download_image(url, folder_name, num):
    # write image to file
    reponse = requests.get(url)
    if reponse.status_code==200:
        with open(os.path.join(folder_name, str(num)+".jpg"), 'wb') as file:
            file.write(reponse.content)


driver = webdriver.Chrome(executable_path=DRIVER_PATH)
search_URL = 'https://www.google.com/search?q=wildlife+photos&tbm=isch&ved=2ahUKEwifgIiK28j7AhViqXIEHZ7wA50Q2-cCegQIABAA&oq=wildli+photos&gs_lcp=CgNpbWcQARgAMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB4yBggAEAcQHjIGCAAQBxAeMgYIABAHEB46BAgAEEM6BQgAEIAEUPcHWMkhYOosaABwAHgAgAG7BIgBzwmSAQc0LjIuNS0xmAEAoAEBqgELZ3dzLXdpei1pbWfAAQE&sclient=img&ei=mWGAY9_PJOLSytMPnuGP6Ak&bih=948&biw=1920'
driver.get(search_URL)

driver.execute_script("window.scrollTo(0, 0);")
page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')

for i in range(1, 151):
    if i % 25 == 0:
        # to skip suggestions in goole
        continue

    xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)

    previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
    previewImageElement = driver.find_element("xpath", previewImageXPath)
    previewImageURL = previewImageElement.get_attribute("src")

    driver.find_element("xpath", xPath).click()

    timeStarted = time.time()
    while True:
        imageElement = driver.find_element("xpath", """//*[@id="Sva75c"]/div/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img""")
        imageURL= imageElement.get_attribute('src')

        if imageURL != previewImageURL: break
        else:  
            currentTime = time.time()
            if currentTime - timeStarted > 10:
                print("Timeout! Will download a lower resolution image and move onto the next one")
                break
    #Downloading image
    try:
        download_image(imageURL, folder_name, i)
        print("Downloaded element %s out of %s total. URL: %s" % (i, 151, imageURL))
    except:
        print("Couldn't download an image %s, continuing downloading the next one"%(i))
# Out:
# /tmp/ipykernel_12018/329624398.py:25: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=DRIVER_PATH)
# Timeout! Will download a lower resolution image and move onto the next one
# Couldn't download an image 1, continuing downloading the next one
# Couldn't download an image 2, continuing downloading the next one
# Downloaded element 3 out of 151 total. URL: https://i.guim.co.uk/img/media/f75f84778dc6c20e519223cdd39ec0f974f2c9b0/0_239_3583_2150/master/3583.jpg?width=1200&height=900&quality=85&auto=format&fit=crop&s=679a9ea087d210112f70eda780c6fed1
# Downloaded element 4 out of 151 total. URL: https://cdn.theatlantic.com/media/img/photo/2021/12/peoples-choice-wildlife-photographe/a01_MarcoGaiotti-1/original.jpg
# Downloaded element 5 out of 151 total. URL: http://cdn.cnn.com/cnnnext/dam/assets/211130161931-26-wildlife-photographer-peoples-choice-shortlist-2021-scli-intl-gbr.jpg
# Timeout! Will download a lower resolution image and move onto the next one
# Couldn't download an image 6, continuing downloading the next one
# Downloaded element 7 out of 151 total. URL: https://i.natgeofe.com/n/af4581b1-84a3-40ba-88eb-3017f2e3b4a8/cheetah-mosaic_2x1.jpg
# Downloaded element 8 out of 151 total. URL: https://imageio.forbes.com/specials-images/imageserve/60bb9a03824a727e00a753d1/A-lion-cub-playing-on-the-carcass-of-a-giraffe-/960x0.jpg?format=jpg&width=960
# Downloaded element 9 out of 151 total. URL: https://thewildlifecollective.com/wp-content/uploads/2020/11/D30I1244-v2-copy-16x9-1-scaled.jpg
# Downloaded element 10 out of 151 total. URL: https://i.natgeofe.com/n/42dfedf7-cc27-4ffd-9a1f-4e3da0743209/nationalgeographic_1777610_3x4.jpg
# Downloaded element 11 out of 151 total. URL: https://i.insider.com/5bf2a2d548eb121808422f62?width=1000&format=jpeg&auto=webp
# Downloaded element 12 out of 151 total. URL: https://thumbs.dreamstime.com/b/large-group-african-safari-animals-wildlife-conservation-concept-174172993.jpg
# Downloaded element 13 out of 151 total. URL: https://www.nhm.ac.uk/content/dam/nhmwww/discover/wpy-56/wpy-first-look-2020-image/hannah-vijayan-wpy56-full-width.jpg.thumb.1160.1160.jpg
# Downloaded element 14 out of 151 total. URL: https://static.boredpanda.com/blog/wp-content/uploads/2019/02/wildlife-photos-austrian-photographer-julian-rad-fb1.png
# Downloaded element 15 out of 151 total. URL: https://images.unsplash.com/photo-1575550959106-5a7defe28b56?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxzZWFyY2h8Mnx8d2lsZGxpZmV8ZW58MHx8MHx8&w=1000&q=80
# Downloaded element 16 out of 151 total. URL: https://www.gannett-cdn.com/presto/2019/09/09/USAT/7e50134a-a692-437b-9257-11b0747b0056-01__Adrian_Hirschi_-_Wildlife_Photographer_of_the_Year.JPG
# Downloaded element 17 out of 151 total. URL: https://cdn.theatlantic.com/media/img/photo/2019/10/winners-of-the-wildlife-photographe/w01_Bao-1/original.jpg
# Downloaded element 18 out of 151 total. URL: https://i.insider.com/5f6b83a1e3e76700117161bb?width=600&format=jpeg&auto=webp
# Downloaded element 19 out of 151 total. URL: https://cc-prod.scene7.com/is/image/CCProdAuthor/a-guide-to-wildlife-photography_P1_mobile_360x270?$pjpeg$&jpegSize=200&wid=720
# Downloaded element 20 out of 151 total. URL: https://webunwto.s3.eu-west-1.amazonaws.com/2019-10/why-wildlife.jpg
# Downloaded element 21 out of 151 total. URL: https://static01.nyt.com/images/2022/03/08/science/08SCI-WILDLIFE/08SCI-WILDLIFE-mediumSquareAt3X.jpg
# Downloaded element 22 out of 151 total. URL: https://petapixel.com/assets/uploads/2021/09/Top-Photos-From-the-57th-Wildlife-Photography-of-The-Year-Competition.jpg
# Downloaded element 23 out of 151 total. URL: https://www.shutterstock.com/image-photo/large-group-african-wildlife-animals-260nw-1403039381.jpg
# Downloaded element 24 out of 151 total. URL: https://static-cse.canva.com/blob/562000/robpotter566319unsplashcopy11.jpg
# Downloaded element 26 out of 151 total. URL: https://cdn2.outdoorphotographer.com/2019/06/telephoto-wildlife-technique-feat-481x305.jpg
# Downloaded element 27 out of 151 total. URL: https://nationaltoday.com/wp-content/uploads/2020/03/World-Wildlife-Day-1.jpg
# Downloaded element 28 out of 151 total. URL: https://cdn-afpnk.nitrocdn.com/BgEWMcOYKEoUiTnQXhfKSvRSdRITWbgr/assets/static/optimized/rev-e48f82d/wp-content/uploads/2021/06/Wildlife-Photographer-Image.png
# Downloaded element 29 out of 151 total. URL: https://www.gannett-cdn.com/presto/2022/10/24/USAT/6253d26d-8894-4a38-87ee-6c2f37b1c0d2-7._Miroslav-Srb_Hello-everyone_00001567.jpg
# Downloaded element 30 out of 151 total. URL: https://static.euronews.com/articles/stories/07/15/74/56/1440x810_cmsv2_d2a5e6fd-d3f5-5661-b083-124f264a3c94-7157456.jpg
# Downloaded element 31 out of 151 total. URL: https://travelnevada.com/wp-content/uploads/2021/04/Wildlife_Desktop.jpg
# Downloaded element 32 out of 151 total. URL: https://www.format.com/wp-content/uploads/emily_mesner_wildlife_photography-1.jpg
# Downloaded element 33 out of 151 total. URL: https://www.cnet.com/a/img/resize/dec637b5f93b6c155efc0d8001af7ff03355b5f4/hub/2022/10/20/0680a372-d35f-4a6b-93e1-29bbbc2eb3c4/1-alex-pansier-jumping-jack-00003301.jpg?auto=webp
# Downloaded element 34 out of 151 total. URL: https://www.pangolinphoto.com/wp-content/uploads/2020/05/Low-angle-wild-dog-by-Janine-Krayer-scaled.webp
# Downloaded element 35 out of 151 total. URL: https://www.azolifesciences.com/images/Article_Images/ImageForArticle_714_16449362895935733.jpg
# Downloaded element 36 out of 151 total. URL: https://zoo.sandiegozoo.org/sites/default/files/styles/hero_with_nav_gradient/public/hero/wildlife_hero.jpg?itok=pCvkDL4P
# Downloaded element 37 out of 151 total. URL: https://www.eurotunnel.com/media/articles/wildlife%20in%20france/0-wildlife-in-france-mobile.jpeg?width=500&height=500&mode=crop
# Downloaded element 38 out of 151 total. URL: https://www.wwf.org.uk/sites/default/files/styles/content_slide_image/public/2016-09/panda-to-tree.jpg?h=234e15cf&itok=RT4kZZgo
# Downloaded element 39 out of 151 total. URL: https://i.ytimg.com/vi/0KTRKfSziwE/maxresdefault.jpg
# Downloaded element 40 out of 151 total. URL: https://media.self.com/photos/5e8e2b54f77fc200080d4122/4:3/w_2560%2Cc_limit/pandas-eating-bamboo.jpg
# Downloaded element 41 out of 151 total. URL: https://images.immediate.co.uk/production/volatile/sites/23/2021/11/Thomas-Peschak-Wildlife-Photographer-of-the-Year-7c5825e.jpg
# Downloaded element 42 out of 151 total. URL: https://petapixel.com/assets/uploads/2022/10/The-Funniest-Finalists-of-the-2022-Comedy-Wildlife-Photo-Awards.jpg
# Downloaded element 43 out of 151 total. URL: https://i1.adis.ws/i/canon/get-inspired-wildlife-photography-tips-1-16.9-new_deabd144184a4e6ebe719a8a8d7e5045
# Downloaded element 44 out of 151 total. URL: https://thumbs.dreamstime.com/b/jaguar-watercolor-predator-animals-wildlife-wild-cat-leopard-design-t-shirt-107432074.jpg
# Downloaded element 45 out of 151 total. URL: https://www.balisafarimarinepark.com/wp-content/uploads/2022/09/animals.jpg
# Downloaded element 46 out of 151 total. URL: https://dynaimage.cdn.cnn.com/cnn/q_auto,w_412,c_fill,g_auto,h_232,ar_16:9/http%3A%2F%2Fcdn.cnn.com%2Fcnnnext%2Fdam%2Fassets%2F221020105900-07-comedy-wildlife-photo-awards.jpg
# Downloaded element 47 out of 151 total. URL: https://www.nhm.ac.uk/content/dam/nhmwww/discover/wpy-2022-winning-images/wpy-winning-image-2022-full-width.jpg.thumb.1160.1160.jpg
# Downloaded element 48 out of 151 total. URL: https://media.istockphoto.com/id/1197795305/photo/concept-nature-reserve-conserve-wildlife-reserve-tiger-deer-global-warming-food-loaf-ecology.jpg?s=612x612&w=0&k=20&c=X9OjckavvCFf4bFxG6TjaJCH9IlZ19NJ1R1S9bA-ksY=
# Downloaded element 49 out of 151 total. URL: https://www.wikihow.com/images/thumb/4/40/Be-a-Wildlife-Photographer-Step-5.jpg/v4-460px-Be-a-Wildlife-Photographer-Step-5.jpg.webp
# Downloaded element 51 out of 151 total. URL: https://iso.500px.com/wp-content/uploads/2015/09/wildlifetips_cover.jpeg
# Downloaded element 52 out of 151 total. URL: https://images.pexels.com/photos/247431/pexels-photo-247431.jpeg?cs=srgb&dl=pexels-pixabay-247431.jpg&fm=jpg
# Downloaded element 53 out of 151 total. URL: https://scx2.b-cdn.net/gfx/news/2019/wildlife.jpg
# Downloaded element 54 out of 151 total. URL: https://imageio.forbes.com/specials-images/imageserve/61a5ee273f202ed4e203d8c8/A-jaguar-contemplates-de-desolation-left-by-fires-in-Brazil-s-Pantanal-wetlands-/960x0.jpg?height=473&width=711&fit=bounds
# Downloaded element 55 out of 151 total. URL: https://www.massaudubon.org/var/ezdemo_site/storage/images/site_ma/learn/nature-wildlife/203577-220-eng-US/nature-wildlife.jpg
# Downloaded element 56 out of 151 total. URL: https://www.oipa.org/international/wp-content/uploads/2016/07/tiger.jpg
# Downloaded element 57 out of 151 total. URL: https://akm-img-a-in.tosshub.com/businesstoday/images/story/201207/wildlifephotogrpahy505_062912012546.jpg?size=948:533
# Downloaded element 58 out of 151 total. URL: https://media.npr.org/assets/img/2022/10/12/-fernando-constantino-marti-nez-belmar-1-wildlife-photographer-of-the-year-_custom-d80f7f6abe234697711248fca5192a4f333df5ee.jpg
# Downloaded element 59 out of 151 total. URL: http://www.greenwoodwildlife.org/wp-content/uploads/Greenwood-logo-40th-Ann-reverse-larger-canvas.png?w=240&h=160&crop=1
# Downloaded element 60 out of 151 total. URL: https://i.natgeofe.com/n/1c40801f-ea2a-4d25-b1d2-a01f53c4d364/01-sergey-gorshkov-wildlife-photographer-of-the-year-2020_3x4.jpg
# Downloaded element 61 out of 151 total. URL: https://www.nwf.org/-/media/NEW-WEBSITE/Design/Carousel-Images/Our-Work/carousel_wildlife_conservation_nic_stoltzfus_500x275.ashx
# Downloaded element 62 out of 151 total. URL: https://www.shutterstock.com/image-photo/wildlife-conservation-day-wild-animals-260nw-1494155156.jpg
# Downloaded element 63 out of 151 total. URL: https://media.istockphoto.com/id/496154506/photo/red-deer-stag-in-misty-morning.jpg?s=612x612&w=0&k=20&c=b6WhdEYTbfKfEJUysZvjnMnMlEK6T8F8Nd-njjOEo14=
# Downloaded element 64 out of 151 total. URL: https://cdn2.outdoorphotographer.com/2022/08/telling-animal-stories-jon-mccormack-leopard-457x305.jpg
# Downloaded element 65 out of 151 total. URL: https://lh3.googleusercontent.com/cBL_O59atj8BfTiLh6Vq2SozyzTQ4Lt9rtVD9KpjJ7z1CKhuV9cxSJ-g4PoalQ5rcqOa90wJXBDonDcsWtJ-L8JveYRsGP2Ts9YfTRA=w1200-h675-n-e30-rj-l80
# Downloaded element 66 out of 151 total. URL: https://cc-prod.scene7.com/is/image/CCProdAuthor/a-guide-to-wildlife-photography_P3a_379x502?$pjpeg$&jpegSize=100&wid=379
# Downloaded element 67 out of 151 total. URL: https://mymodernmet.com/wp/wp-content/uploads/2022/04/comedy-wildlife-photography-awards-Greg-Harvey-The-Proposal.jpg
# Downloaded element 68 out of 151 total. URL: http://s3.amazonaws.com/Photo_of_the_Day/system/uploads/photo/image/17135/sized_redfox_hunt_cycle3.jpg
# Downloaded element 69 out of 151 total. URL: https://i0.wp.com/mattsnextsteps.com/wp-content/uploads/2020/09/pexels-flickr-147939-1-scaled.jpg?resize=1140%2C760&ssl=1
# Downloaded element 70 out of 151 total. URL: https://static01.nyt.com/images/2022/03/08/science/08SCI-WILDLIFE/08SCI-WILDLIFE-videoSixteenByNine3000.jpg
# Downloaded element 71 out of 151 total. URL: https://thewildlifemuseum.org/wp-content/uploads/2021/01/website-homepage1.png
# Downloaded element 72 out of 151 total. URL: https://i.cbc.ca/1.6625669.1666386739!/fileImage/httpImage/image.jpg_gen/derivatives/16x9_780/talk-to-the-fin.jpg
# Downloaded element 73 out of 151 total. URL: http://www.nwf.org/-/media/NEW-WEBSITE/Shared-Folder/Magazines/2022/Oct-Nov/front-cover-ON2022-450x591.ashx
# Downloaded element 74 out of 151 total. URL: https://awionline.org/sites/default/files/inline-images/trapping-penning_shutterstock_1495686335.jpg
# Downloaded element 76 out of 151 total. URL: https://images.immediate.co.uk/production/volatile/sites/23/2010/07/GettyImages-153499239-d5b4234.jpg?quality=90&resize=980,654
# Downloaded element 77 out of 151 total. URL: https://www.wwf.org.uk/sites/default/files/styles/social_share_image/public/2016-09/Large_WW11471.jpg?itok=0vyOkmHv
# Downloaded element 78 out of 151 total. URL: https://wildlife.ca.gov/Portals/0/Images/LivingWithWildlife/LWW-banner_lion_9_24_no_levels_818.jpg?ver=2019-09-24-130332-780
# Downloaded element 79 out of 151 total. URL: https://media.wbur.org/wp/2019/08/GrooM-1-2-1000x667.jpg
# Downloaded element 80 out of 151 total. URL: https://imageio.forbes.com/specials-images/imageserve/61a5eaf57da3fe54c41a7123/0x0.jpg?format=jpg&crop=1280,721,x0,y65,safe&width=1200
# Downloaded element 81 out of 151 total. URL: https://studiowildlife.com/wp-content/uploads/2020/02/daniel-jag-750x500.jpg
# Downloaded element 82 out of 151 total. URL: https://i.insider.com/5bf29fe948eb1262ae77eaa2?width=1000&format=jpeg&auto=webp
# Downloaded element 83 out of 151 total. URL: https://www.nhm.ac.uk/content/dam/nhmwww/visit/Exhibitions/wpy58/wpy58-giraffe-hero.jpg.thumb.1920.1920.jpg
# Downloaded element 84 out of 151 total. URL: https://media.gettyimages.com/id/626056254/photo/clumsy-nature-photographer-dont-find-the-kingfisher-on-the-lens.jpg?s=612x612&w=gi&k=20&c=qf0UVXIodJ67j0xQvscxAsA_OVuON3TkiDgQbbjuMz0=
# Downloaded element 85 out of 151 total. URL: https://www.ndow.org/wp-content/uploads/2021/09/home-hero.jpeg
# Downloaded element 86 out of 151 total. URL: https://www.vet.upenn.edu/images/default-source/reasearch/pa-wildlife-futures/wildlife-sliders/raccon-1500x580.jpg?sfvrsn=2d7ef0ba_6
# Downloaded element 87 out of 151 total. URL: https://images.unsplash.com/photo-1535941339077-2dd1c7963098?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxzZWFyY2h8OXx8d2lsZGxpZmV8ZW58MHx8MHx8&w=1000&q=80
# Downloaded element 88 out of 151 total. URL: https://static.wixstatic.com/media/5d110d_3d21d8f0c7f74d68abdee59f2f642829~mv2.jpg/v1/fill/w_770,h_432,al_c,q_80,usm_0.66_1.00_0.01,enc_auto/Present%20this%20coupon%20during%20purchase.jpg
# Downloaded element 89 out of 151 total. URL: https://www.rei.com/dam/butler_091914_0065_hero_lg.jpg
# Downloaded element 90 out of 151 total. URL: https://www.fws.gov/sites/default/files/styles/banner_image_xs/public/banner_images/2021-07/PipingPlover-AmagansettRefuge-NY-USFWS.jpg?h=724b8866&itok=0X7MasYr
# Downloaded element 91 out of 151 total. URL: https://ichef.bbci.co.uk/news/976/cpsprodpb/10231/production/_123179066_qiang-guo-wildlife-photographer-of-the-year.jpg
# Downloaded element 92 out of 151 total. URL: https://www.globalwildlife.org/wp-content/uploads/2020/10/main-collage-horizontal-full-background.jpg
# Downloaded element 93 out of 151 total. URL: https://wildlife.org/wp-content/uploads/2022/11/1_Wolf_Mira-Sytsma.jpeg
# Downloaded element 94 out of 151 total. URL: http://cdn.cnn.com/cnnnext/dam/assets/220830062745-13-wildlife-photographer-of-the-year-2022-restricted.jpg
# Downloaded element 95 out of 151 total. URL: https://wallpaperaccess.com/full/2251377.jpg
# Downloaded element 96 out of 151 total. URL: https://files.worldwildlife.org/wwfcmsprod/images/HERO_Tiger_Grass_WEB_ONLY_thru_12_31_2017/hero_small/2b4gkcgq26_20150513_JWA7615_web.jpg
# Downloaded element 97 out of 151 total. URL: https://www.bu.edu/files/2022/03/feat-iStock-1333294167.jpg
# Downloaded element 98 out of 151 total. URL: https://www.treehugger.com/thmb/tsKodDOsdamZgr7XgndZD4UwOvU=/335x224/filters:no_upscale():max_bytes(150000):strip_icc()/giraffe-eating-2-1406593651-cd6b78e84df641b0ba0749dff117ec97.jpg
# Timeout! Will download a lower resolution image and move onto the next one
# Downloaded element 99 out of 151 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZZPBf9pQcTACBVjNwQbAiPr5QyWRxMx6GJQ&usqp=CAU
# Downloaded element 101 out of 151 total. URL: https://ipt.imgix.net/203021/x/0/
# Downloaded element 102 out of 151 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDUld-bDtT3CVvzuQeN2yZg6rscN-Ql4ddAe_05otwuytoTxulqAF0dxgvkprCRNLwq3w&usqp=CAU
# Downloaded element 103 out of 151 total. URL: https://awionline.org/sites/default/files/inline-images/lethal-nonlethal-animal-control_shutterstock_1944088450.jpg
# Downloaded element 104 out of 151 total. URL: https://static.boredpanda.com/blog/wp-content/uploads/2018/10/5bc8a07ead44b__700-png.jpg
# Downloaded element 105 out of 151 total. URL: https://awionline.org/sites/default/files/inline-images/lethal-nonlethal-animal-control_shutterstock_1944088450.jpg
# Downloaded element 106 out of 151 total. URL: https://static.boredpanda.com/blog/wp-content/uploads/2018/10/5bc8a07ead44b__700-png.jpg
# Downloaded element 107 out of 151 total. URL: https://iso.500px.com/wp-content/uploads/2020/09/Playful-Leopard-Cub-By-Will-Burrard-Lucas.jpeg
# Downloaded element 108 out of 151 total. URL: https://ipt.imgix.net/203021/x/0/
# Downloaded element 109 out of 151 total. URL: https://www.blog.motifphotos.com/wp-content/uploads/2020/07/iStock-496206758-1200x812.jpg
# Downloaded element 110 out of 151 total. URL: https://www.jessleephotos.com/images/640/druid-wolf-photo-312.jpg
# Downloaded element 111 out of 151 total. URL: https://defenders.org/sites/default/files/styles/meta_image/public/2020-04/Grizzly%20mother%20and%20yearling%20cubs%20in%20Grand%20Teton%20National%20Park%20in%20yellow%20flowers%20HEADER%20Dianne%20Lethcoe.jpg?itok=avfWGHun
# Downloaded element 112 out of 151 total. URL: https://webneel.com/daily/sites/default/files/images/daily/09-2013/19-wildlife-photography.jpg
# Downloaded element 113 out of 151 total. URL: https://static.independent.co.uk/s3fs-public/thumbnails/image/2020/07/25/12/stop-the-wildlife-trade-shaaz-jung-1.jpg?quality=75&width=640&height=614&fit=bounds&format=pjpg&crop=16%3A9%2Coffset-y0.5&auto=webp
# Timeout! Will download a lower resolution image and move onto the next one
# Downloaded element 114 out of 151 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT3tF-ITXwrCanGNj9i7gnL0jC8CU9eAsBIYtbT3jyDiFflweHUYZWDpvtGYw2nu7xtrDo&usqp=CAU
# Downloaded element 115 out of 151 total. URL: https://photographylife.com/wp-content/uploads/2022/05/Curve_Billed_Thrasher_On_Stick-1.jpg
# Downloaded element 116 out of 151 total. URL: https://www.ephotozine.com/articles/10-top-examples-of-wildlife---nature-photography-21080/images/welcome_cooler.jpg
# Downloaded element 117 out of 151 total. URL: https://media.audleytravel.com/-/media/images/home/africa/madagascar/country-guides/wildlife-of-madagascar/496277746_lemur_3000x1000.jpg
# Downloaded element 118 out of 151 total. URL: https://wildlifesos.org/wp-content/uploads/2020/12/leopard-quote-1-900x600.jpg
# Downloaded element 119 out of 151 total. URL: https://akm-img-a-in.tosshub.com/businesstoday/images/story/201207/wildlifephotogrpahy505_062912012546.jpg?size=948:533
# Downloaded element 120 out of 151 total. URL: https://i.ytimg.com/vi/IUWJ8_lkFAA/maxresdefault.jpg
# Downloaded element 121 out of 151 total. URL: https://i.etsystatic.com/36886524/r/il/d13969/4235884603/il_fullxfull.4235884603_epkt.jpg
# Downloaded element 122 out of 151 total. URL: https://media.timeout.com/images/105941180/750/422/image.jpg
# Downloaded element 123 out of 151 total. URL: https://rewildingeurope.com/wp-content/uploads/2017/11/SWD-2008-07-11-180703-01-1024x725.jpg
# Downloaded element 124 out of 151 total. URL: https://www.massaudubon.org/var/ezdemo_site/storage/images/site_ma/site-config/top/learn/explore-native-wildlife/482843-14-eng-US/explore-native-wildlife_navitemfeature.jpg
# Downloaded element 126 out of 151 total. URL: https://wildlife-rescue.org/wp-content/uploads/2014/12/thumb_monkey3.jpg
# Downloaded element 127 out of 151 total. URL: https://lnt.org/wp-content/uploads/2018/11/goat.jpg
# Downloaded element 128 out of 151 total. URL: https://www.humanesociety.org/sites/default/files/styles/768x326/public/2022-07/raptor-rehab-575033.jpg?h=e22bf01e&itok=RLQ_bd2S
# Downloaded element 129 out of 151 total. URL: https://explore.panda.org/hubfs/Small_WW22658.jpg
# Downloaded element 130 out of 151 total. URL: https://static.wixstatic.com/media/d863d4_37571a2b05f64380bcf273678c81066b~mv2.jpg/v1/fill/w_982,h_878,al_c,q_85,usm_0.66_1.00_0.01,enc_auto/d863d4_37571a2b05f64380bcf273678c81066b~mv2.jpg
# Timeout! Will download a lower resolution image and move onto the next one
# Downloaded element 131 out of 151 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRvnlAn26HTRyrUN23YwdwjTZyTsvxyQ992TQ&usqp=CAU
# Downloaded element 132 out of 151 total. URL: https://www.picturecorrect.com/wp-content/uploads/2017/12/capturing-wildlife-tips.jpg
# Downloaded element 133 out of 151 total. URL: https://pbs.twimg.com/media/FiLadC8VUAAYu_9?format=jpg&name=large
# Downloaded element 134 out of 151 total. URL: https://www.wildlifetrusts.org/sites/default/files/styles/spotlight_default/public/2017-12/Kingfisher%20%C2%A9jonhawkinsSurreyHillsPhotography.jpg?h=7d6ddefd&itok=WwXfmIDl
# Timeout! Will download a lower resolution image and move onto the next one
# Downloaded element 135 out of 151 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQfunPMAOvd5Wa1TAd9lrYy1IZHCDbr3NK8bA&usqp=CAU
# Downloaded element 136 out of 151 total. URL: https://www.unodc.org/images/data-and-analysis/toc/coverWorld_Wildlife_Report_2020_9July.png
# Downloaded element 137 out of 151 total. URL: https://media.npr.org/assets/img/2021/11/18/arthur-trevino_ninja-prairie-dog-copy_custom-6f0ca2eee0a106a86afbf3e49f5b93a3fac6a422-s1100-c50.jpg
# Timeout! Will download a lower resolution image and move onto the next one
# Downloaded element 138 out of 151 total. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSx46dwtKbyIXkzbK30yoU0pPEhtlvBhuN4NQ&usqp=CAU
# Downloaded element 139 out of 151 total. URL: https://cdn.pixabay.com/photo/2018/07/14/17/46/raccoon-3538081__340.jpg
# Downloaded element 140 out of 151 total. URL: https://www.shutterstock.com/shutterstock/photos/1078246298/display_1500/stock-photo-predator-s-love-lioness-and-cub-in-the-kruger-np-south-africa-1078246298.jpg
# Downloaded element 141 out of 151 total. URL: https://share.america.gov/wp-content/uploads/2015/02/sumatran-tiger-shutterstock_51145033.jpg
# Downloaded element 142 out of 151 total. URL: https://mymodernmet.com/wp/wp-content/uploads/2021/01/simon-needham-wildlife-photography-2.jpg
# Downloaded element 143 out of 151 total. URL: http://animalark.org/wp-content/uploads/2020/08/mountain-lion.jpg
# Downloaded element 144 out of 151 total. URL: https://www.outdoorphotographer.com/images/stories/2016/apr/wildlife/2.jpg
# Downloaded element 145 out of 151 total. URL: https://www.bayouwildlifezoo.com/image/134575626.jpg
# Downloaded element 146 out of 151 total. URL: https://www.vet.upenn.edu/images/default-source/reasearch/pa-wildlife-futures/wildlife-sliders/great-blue-heron-on-snag-jacob-dingel-1500-copy.jpg?sfvrsn=33a1f5ba_2
# Downloaded element 147 out of 151 total. URL: https://www.fws.gov/sites/default/files/styles/banner_image_xs/public/banner_images/2022-01/blue%20winged%20teal.jpg?h=9e1f9c7f&itok=u2DBbR9b
# Downloaded element 148 out of 151 total. URL: https://wildlife.org/wp-content/uploads/2014/05/about-tws.jpg
# Downloaded element 149 out of 151 total. URL: https://webneel.com/daily/sites/default/files/images/daily/05-2013/22-best-wildlife-photography.jpg

# %%
#from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import cv2
import sys
import numpy as np
from skimage import segmentation
import torch.nn.init

use_cuda = torch.cuda.is_available()
maxIter = 30
channels = 100
conv=2
minLabels = 3
visualize = False

class SegNet(nn.Module):
    def __init__(self,input_dim, nChannel, nConv):
        super(SegNet, self).__init__()
        self.nConv = nConv
        self.conv1 = nn.Conv2d(input_dim, 100, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(nChannel)
        self.conv2 = nn.ModuleList()
        self.bn2 = nn.ModuleList()
        for i in range(1):
            self.conv2.append( nn.Conv2d(100, 100, kernel_size=3, stride=1, padding=1))
            self.bn2.append( nn.BatchNorm2d(100))
        self.conv3 = nn.Conv2d(100, 100, kernel_size=1, stride=1, padding=0)
        self.bn3 = nn.BatchNorm2d(nChannel)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.bn1(x)
        for i in range(1):
            x = self.conv2[i](x)
            x = F.relu(x)
            x = self.bn2[i](x)
        x = self.conv3(x)
        x = self.bn3(x)
        return x

def slic_feature_extraction(img):
    lab = segmentation.slic(img, compactness=100, n_segments=10000)
    lab = lab.reshape(img.shape[0]*img.shape[1])
    unique = np.unique(lab)
    slic_feat = []
    for i in range(len(unique)):
        slic_feat.append( np.where(lab == unique[i])[0])

    return slic_feat


def load_img(img_path):
    img = cv2.resize(cv2.imread(img_path), (500,500))
    data = torch.from_numpy(np.array([img.transpose((2, 0, 1)).astype('float32')/255.]))
    if use_cuda: data = data.cuda()
    data = Variable(data)

    return data, img

def train(data,img, slic_feat, out_path):

    model = SegNet(data.size(1), channels, conv)
    if use_cuda: model.cuda()

    model.train()

    loss_fn = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
    label_colours = np.random.randint(255,size=(100,3))

    for batch_idx in range(maxIter):
        optimizer.zero_grad()
        
        output = model(data)[0]
        output = output.permute(1,2,0).contiguous().view(-1, channels)
        ignore, target = torch.max( output, 1 )
        im_target = target.data.cpu().numpy()
        nLabels = len(np.unique(im_target))
        
        if visualize:
            out_im = np.array([label_colours[ c % 100 ] for c in im_target])
            out_im = out_im.reshape(img.shape).astype( np.uint8 )
            cv2.imshow( "output", out_im )
            cv2.waitKey(10)

        # improving segmenration using superpixel
        for i in range(len(slic_feat)):
            labels_per_sp = im_target[slic_feat[i]]
            u_labels_per_sp = np.unique( labels_per_sp )
            hist = np.zeros(len(u_labels_per_sp))
            for j in range(len(hist)):
                hist[j] = len( np.where( labels_per_sp == u_labels_per_sp[j])[0] )
            im_target[slic_feat[i]] = u_labels_per_sp[np.argmax(hist)]
        target = torch.from_numpy( im_target )

        if use_cuda: target = target.cuda()

        target = Variable(target)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        if batch_idx % 10== 0: print (batch_idx, '/', maxIter, ':', nLabels, loss.item())

        if nLabels <= minLabels:
            print ("nLabels", nLabels, "reached minLabels", minLabels, ".")
            break

    if not visualize:
        output = model(data)[0]
        output = output.permute(1,2,0).contiguous().view( -1, channels)
        ignore, target = torch.max(output, 1)
        im_target = target.data.cpu().numpy()
        out_im = np.array([label_colours[c % 100] for c in im_target])
        out_im = out_im.reshape(img.shape).astype(np.uint8)
    cv2.imwrite(out_path, out_im)


def unsuper_Seg(file_path, out_path):

    data, img = load_img(file_path)
    slic_feat = slic_feature_extraction(img)

    train(data, img, slic_feat, out_path)

# %%
folder = './demo_data'
out = './segmented_demo_data'

for file in os.listdir(folder):
    file_path = os.path.join(folder, file)
    out_path = os.path.join(out, file)
    print(file_path)

    unsuper_Seg(file_path, out_path)
# Out:
# ./demo_data/adelina-tuca-profile.jpg
# 0 / 30 : 99 3.463144302368164
# 10 / 30 : 17 2.046722888946533
# 20 / 30 : 5 0.3239264190196991
# ./demo_data/wildlife.jpg
# 0 / 30 : 100 3.4706883430480957
# 10 / 30 : 30 1.6842962503433228
# 20 / 30 : 10 0.4387589395046234
# ./demo_data/nature_1.jpeg
# 0 / 30 : 100 3.765160083770752
# 10 / 30 : 36 2.1157238483428955
# 20 / 30 : 8 0.5479351282119751
# ./demo_data/nature_2.jpeg
# 0 / 30 : 100 3.785759210586548
# 10 / 30 : 27 1.5715562105178833
# 20 / 30 : 16 0.5876234173774719
# ./demo_data/dog.jpg
# 0 / 30 : 100 3.5409247875213623
# 10 / 30 : 43 2.3177425861358643
# 20 / 30 : 17 0.753579318523407
